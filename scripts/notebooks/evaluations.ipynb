# %%
# %load_ext autoreload
# %autoreload 2

# %%
from kt_simul.core import simul_spindle as sim
from kt_simul.io.simuio import SimuIO

# %%
meta = SimuIO().read("../results.zip", verbose=True)
# Out:
# 2012/10/31-16:53:44:INFO: Parameters loaded
# 2012/10/31-16:53:44:INFO: Simulation initialized

# %%
res = meta.evaluate(name='Mitotic Plate', debug=True, verbose=True, draw=True)
# Out:
# 2012/10/31-16:58:33:INFO: Running Mitotic Plate
# 2012/10/31-16:58:34:INFO: Mitotic Plate done

# %%
plt.show()
