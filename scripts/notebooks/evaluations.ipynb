# %%
# %load_ext autoreload
# %autoreload 2

# %%
from kt_simul.core import simul_spindle as sim
from kt_simul.io.simuio import SimuIO

# %%
meta = SimuIO().read("../results.zip", verbose=True)
# Out:
# 2012/10/30-13:19:15:INFO: Parameters loaded
# 2012/10/30-13:19:15:INFO: Simulation initialized

# %%
res = meta.evaluate(name='Kinetochores Trajectories', debug=True, verbose=True, draw=True)
# Out:
# 2012/10/30-13:20:00:INFO: Running Kinetochores Trajectories
# 2012/10/30-13:20:00:INFO: Kinetochores Trajectories done

# %%
print res
# Out:
# {'spbL': array([-0.15      , -0.15816833, -0.16638489, ..., -2.04535627,
#        -2.04750562, -2.04900265]), 'chromosomes': [{'Chromo0_CenRight': array([ 0.01861953, -0.02199291, -0.0591261 , ..., -2.04535627,
#        -2.04535627, -2.04900265]), 'Chromo0_CenLeft': array([-0.08138047, -0.0785523 , -0.078007  , ...,  2.04385924,
#         2.04750562,  2.04750562])}, {'Chromo1_CenRight': array([ 0.10377432,  0.1001679 ,  0.09787244, ...,  2.04385924,
#         2.04750562,  2.04750562]), 'Chromo1_CenLeft': array([ 0.00377432,  0.02356025,  0.04119882, ..., -2.04535627,
#        -2.04535627, -2.04900265])}, {'Chromo2_CenRight': array([ 0.0995215 ,  0.09260426,  0.06810938, ..., -2.04385924,
#        -2.04750562, -2.04750562]), 'Chromo2_CenLeft': array([ -4.78497893e-04,  -4.61868709e-04,  -7.92585430e-04, ...,
#          2.04385924e+00,   2.04750562e+00,   2.04750562e+00])}], 'spbR': array([ 0.15      ,  0.15816833,  0.16638489, ...,  2.04535627,
#         2.04750562,  2.04900265])}
