# %%
# %load_ext autoreload
# %autoreload 2

# %%
from kt_simul.core import simul_spindle as sim
from kt_simul.io.simuio import SimuIO
from kt_simul.draw import Drawer

# %%
meta = SimuIO().read("results.zip", verbose=True)
# Out:
# 2012/10/26-11:50:20:INFO: Parameters loaded
# 2012/10/26-11:50:20:INFO: Simulation initialized

# %%
res = meta.evaluate(name='Kineto Attachment', debug=True, verbose=True, draw=True)
# Out:
# 2012/10/26-12:28:42:INFO: Running Kineto Attachment
# 2012/10/26-12:28:43:INFO: Kineto Attachment done
